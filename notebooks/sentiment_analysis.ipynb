# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install textblob
from src.data_utils import load_data
from src.sentiment_labeler import apply_sentiment
from src.scoring import compute_monthly_scores
from src.flightrisk import detect_flight_risk
from src.modeling import build_regression_model
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\VENKAT REDDY\AppData\Roaming\Python\Python311\site-packages)
# DEPRECATION: Loading egg at c:\program files\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\VENKAT REDDY\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~etuptools (C:\Users\VENKAT REDDY\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = load_data("../data/test.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = load_data("../data/test.csv.xlsx")
#       2 df.head()
#
# File c:\Users\VENKAT REDDY\Desktop\ai-project\src\data_utils.py:4, in load_data(path)
#       3 def load_data(path):
# ----> 4     df = pd.read_csv("C:\\Users\\VENKAT REDDY\\Desktop\\ai-project\\data\\test.csv.xlsx")
#       5     return df
#
# ...

# %%
df = apply_sentiment(df)
df.head()

# %%
sns.countplot(x="sentiment", data=df)
plt.title("Sentiment Distribution")
plt.show()

# %%
df["msg_len"] = df["message"].str.len()

sns.histplot(df["msg_len"], bins=40)
plt.title("Message Length Distribution")
plt.show()

# %%
monthly_scores = compute_monthly_scores(df)
monthly_scores.head()

# %%
risk_employees = detect_flight_risk(df)
risk_employees

# %%
results = build_regression_model(df)
results
